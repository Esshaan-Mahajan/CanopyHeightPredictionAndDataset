# %%
#https://github.com/yandex-research/rtdl/blob/main/projects/revisiting-models/bin/resnet.py

# %%
# !wget https://www.dropbox.com/s/o53umyg6mn3zhxy/rtdl_data.tar.gz?dl=1 -O rtdl_revisiting_models_data.tar.gz
# Out:
# --2022-06-10 04:02:49--  https://www.dropbox.com/s/o53umyg6mn3zhxy/rtdl_data.tar.gz?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/o53umyg6mn3zhxy/rtdl_data.tar.gz [following]
# --2022-06-10 04:02:49--  https://www.dropbox.com/s/dl/o53umyg6mn3zhxy/rtdl_data.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucd15bc032c072eeabf5119288f5.dl.dropboxusercontent.com/cd/0/get/Bm4_vL_kyYSt9T5JIl4jaJjvvknBHS3B6LG5n9GZpt_K1TRYf8611Ren9G13MDxyLNK_vIKfky71UPqTPtsDQWfrUqAu84X4Jv6ydWleWeSC68RhUI0O8U1Wu8ErMmbsKn9Z298wqgNVM3w2J2a2aEGEOCMPX1p5G4bUWVBTHV4H0-uO7KN4_sMS8-dLu3Yc1DE/file?dl=1# [following]
# --2022-06-10 04:02:49--  https://ucd15bc032c072eeabf5119288f5.dl.dropboxusercontent.com/cd/0/get/Bm4_vL_kyYSt9T5JIl4jaJjvvknBHS3B6LG5n9GZpt_K1TRYf8611Ren9G13MDxyLNK_vIKfky71UPqTPtsDQWfrUqAu84X4Jv6ydWleWeSC68RhUI0O8U1Wu8ErMmbsKn9Z298wqgNVM3w2J2a2aEGEOCMPX1p5G4bUWVBTHV4H0-uO7KN4_sMS8-dLu3Yc1DE/file?dl=1
# Resolving ucd15bc032c072eeabf5119288f5.dl.dropboxusercontent.com (ucd15bc032c072eeabf5119288f5.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to ucd15bc032c072eeabf5119288f5.dl.dropboxusercontent.com (ucd15bc032c072eeabf5119288f5.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4372449836 (4.1G) [application/binary]
# Saving to: ‘rtdl_revisiting_models_data.tar.gz’
#
# rtdl_revisiting_mod 100%[===================>]   4.07G  93.2MB/s    in 48s
#
# 2022-06-10 04:03:38 (87.2 MB/s) - ‘rtdl_revisiting_models_data.tar.gz’ saved [4372449836/4372449836]

# %%
# !pip install -r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting black
#   Downloading black-22.3.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 5.1 MB/s
# Requirement already satisfied: coverage in /usr/local/lib/python3.7/dist-packages (from -r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 3)) (3.7.1)
# Collecting flake8
#   Downloading flake8-4.0.1-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.6 MB/s
# Collecting flit
#   Downloading flit-3.7.1-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.3 MB/s
# Collecting ipdb
#   Downloading ipdb-0.13.9.tar.gz (16 kB)
# Collecting isort
#   Downloading isort-5.10.1-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 48.2 MB/s
# Collecting mypy
#   Downloading mypy-0.961-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 24.7 MB/s
# Collecting pre-commit-hooks
#   Downloading pre_commit_hooks-4.3.0-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.0 MB/s
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from -r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 10)) (3.6.4)
# Collecting sphinx==4.2.0
#   Downloading Sphinx-4.2.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 37.0 MB/s
# Collecting sphinx-copybutton
#   Downloading sphinx_copybutton-0.5.0-py3-none-any.whl (12 kB)
# Collecting sphinx-material
#   Downloading sphinx_material-0.0.35-py3-none-any.whl (790 kB)
#      |████████████████████████████████| 790 kB 56.0 MB/s
# Collecting sphinxcontrib-spelling
#   Downloading sphinxcontrib_spelling-7.5.0-py3-none-any.whl (15 kB)
# Collecting jupyterlab
#   Downloading jupyterlab-3.4.3-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 45.7 MB/s
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (2.23.0)
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 8.9 MB/s
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.7/dist-packages (from sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (2.10.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/dist-packages (from sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (0.7.12)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.7/dist-packages (from sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (1.3.0)
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.2 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (57.4.0)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 42.8 MB/s
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.7/dist-packages (from sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (2.11.3)
# Requirement already satisfied: docutils<0.18,>=0.14 in /usr/local/lib/python3.7/dist-packages (from sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (0.17.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.7/dist-packages (from sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (2.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (21.3)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (1.1.5)
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.7/dist-packages (from sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (2.6.1)
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 9.8 MB/s
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.7/dist-packages (from babel>=1.3->sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (2022.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.3->sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (2.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (2.10)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from black->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 2)) (2.0.1)
# Collecting click>=8.0.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 5.7 MB/s
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting platformdirs>=2
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Collecting typed-ast>=1.4.2
#   Downloading typed_ast-1.5.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (843 kB)
#      |████████████████████████████████| 843 kB 30.3 MB/s
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.7/dist-packages (from black->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 2)) (4.2.0)
# Collecting pathspec>=0.9.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from click>=8.0.0->black->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 2)) (4.11.4)
# Collecting pyflakes<2.5.0,>=2.4.0
#   Downloading pyflakes-2.4.0-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 7.2 MB/s
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.2.0-py3-none-any.whl (16 kB)
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting pycodestyle<2.9.0,>=2.8.0
#   Downloading pycodestyle-2.8.0-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 833 kB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->click>=8.0.0->black->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 2)) (3.8.0)
# Collecting tomli-w
#   Downloading tomli_w-1.0.0-py3-none-any.whl (6.0 kB)
# Collecting flit_core>=3.7.1
#   Downloading flit_core-3.7.1-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 6.6 MB/s
# Collecting ipython>=7.17.0
#   Downloading ipython-7.34.0-py3-none-any.whl (793 kB)
#      |████████████████████████████████| 793 kB 23.7 MB/s
# Collecting toml>=0.10.2
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipdb->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 6)) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.17.0->ipdb->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 6)) (0.18.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=7.17.0->ipdb->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 6)) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.17.0->ipdb->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 6)) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.17.0->ipdb->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 6)) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.7/dist-packages (from ipython>=7.17.0->ipdb->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 6)) (0.1.3)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=7.17.0->ipdb->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 6)) (0.2.0)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.29-py3-none-any.whl (381 kB)
#      |████████████████████████████████| 381 kB 47.8 MB/s
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython>=7.17.0->ipdb->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 6)) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->ipython>=7.17.0->ipdb->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 6)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.17.0->ipdb->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 6)) (0.2.5)
# Collecting ruamel.yaml>=0.15
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 3.6 MB/s
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.6-cp37-cp37m-manylinux1_x86_64.whl (546 kB)
#      |████████████████████████████████| 546 kB 47.4 MB/s
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 10)) (21.4.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 10)) (8.13.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 10)) (1.4.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 10)) (0.7.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from pytest->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 10)) (1.15.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 10)) (1.11.0)
# Collecting css-html-js-minify
#   Downloading css_html_js_minify-2.5.5-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.1 MB/s
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from sphinx-material->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 16)) (4.2.6)
# Requirement already satisfied: python-slugify[unidecode] in /usr/local/lib/python3.7/dist-packages (from sphinx-material->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 16)) (6.1.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from sphinx-material->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 16)) (4.6.3)
# Collecting PyEnchant>=3.1.1
#   Downloading pyenchant-3.2.2-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.6 MB/s
# Collecting tornado>=6.1.0
#   Downloading tornado-6.1-cp37-cp37m-manylinux2010_x86_64.whl (428 kB)
#      |████████████████████████████████| 428 kB 56.2 MB/s
# Collecting nbclassic~=0.2
#   Downloading nbclassic-0.3.7-py3-none-any.whl (13 kB)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (4.10.0)
# Collecting jupyter-server~=1.16
#   Downloading jupyter_server-1.17.1-py3-none-any.whl (344 kB)
#      |████████████████████████████████| 344 kB 59.4 MB/s
# Collecting jupyterlab-server~=2.10
#   Downloading jupyterlab_server-2.14.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.8 MB/s
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 8.7 MB/s
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (23.0.0)
# Collecting jupyter-client>=6.1.12
#   Downloading jupyter_client-7.3.4-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 56.5 MB/s
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (0.14.1)
# Collecting websocket-client
#   Downloading websocket_client-1.3.2-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.2 MB/s
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (21.3.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (0.13.3)
# Requirement already satisfied: nbformat>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (5.4.0)
# Collecting nbconvert>=6.4.4
#   Downloading nbconvert-6.5.0-py3-none-any.whl (561 kB)
#      |████████████████████████████████| 561 kB 47.9 MB/s
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.12->jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.12->jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (1.5.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.12->jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (2.8.2)
# Collecting Jinja2>=2.3
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 41.0 MB/s
# Collecting json5
#   Downloading json5-0.9.8.tar.gz (22 kB)
# Requirement already satisfied: jsonschema>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from jupyterlab-server~=2.10->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (5.7.1)
# Requirement already satisfied: notebook<7 in /usr/local/lib/python3.7/dist-packages (from nbclassic~=0.2->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (5.3.1)
# Collecting notebook-shim>=0.1.0
#   Downloading notebook_shim-0.1.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (0.2.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (1.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (0.6.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (5.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (0.7.1)
# Collecting traitlets>=4.2
#   Downloading traitlets-5.2.2.post1-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 49.1 MB/s
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat>=5.2.0->jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (2.15.3)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.7/dist-packages (from notebook<7->nbclassic~=0.2->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (4.10.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from notebook<7->nbclassic~=0.2->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (0.2.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.7/dist-packages (from argon2-cffi->jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (2.21)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 20)) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->sphinx==4.2.0->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 14)) (3.0.9)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify[unidecode]->sphinx-material->-r https://raw.githubusercontent.com/manmeet3591/rtdl/main/requirements_dev.txt (line 16)) (1.3)
# Collecting Unidecode>=1.1.1
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 53.2 MB/s
# Building wheels for collected packages: ipdb, json5
#   Building wheel for ipdb (setup.py) ... done
#   Created wheel for ipdb: filename=ipdb-0.13.9-py3-none-any.whl size=11648 sha256=d1f170889855603daa3ddbcfb537ee0aae8955053f750e05d1c17c3e1c87ddea
#   Stored in directory: /root/.cache/pip/wheels/65/cd/cc/aaf92acae337a28fdd2aa4d632196a59745c8c39f76eaeed01
#   Building wheel for json5 (setup.py) ... done
#   Created wheel for json5: filename=json5-0.9.8-py2.py3-none-any.whl size=18604 sha256=db837b2e94239585021621e8c4d0eac2809025dbd9e72dc6466493dbe0b69e1b
#   Stored in directory: /root/.cache/pip/wheels/ac/9b/de/6e4fd8f159d3dfa42c42ceddf2184fda29ea7fb1e8f5f8371c
# Successfully built ipdb json5
# Installing collected packages: traitlets, importlib-metadata, tornado, jupyter-client, sniffio, prompt-toolkit, Jinja2, websocket-client, nbconvert, ipython, anyio, jupyter-server, Unidecode, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, ruamel.yaml.clib, notebook-shim, json5, typed-ast, tomli-w, toml, sphinx, ruamel.yaml, pyflakes, PyEnchant, pycodestyle, platformdirs, pathspec, nbclassic, mypy-extensions, mccabe, jupyterlab-server, flit-core, css-html-js-minify, click, sphinxcontrib-spelling, sphinx-material, sphinx-copybutton, pre-commit-hooks, mypy, jupyterlab, isort, ipdb, flit, flake8, black
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.1.1
#     Uninstalling traitlets-5.1.1:
#       Successfully uninstalled traitlets-5.1.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.4
#     Uninstalling importlib-metadata-4.11.4:
#       Successfully uninstalled importlib-metadata-4.11.4
#   Attempting uninstall: tornado
#     Found existing installation: tornado 5.1.1
#     Uninstalling tornado-5.1.1:
#       Successfully uninstalled tornado-5.1.1
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 5.3.5
#     Uninstalling jupyter-client-5.3.5:
#       Successfully uninstalled jupyter-client-5.3.5
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 1.0.18
#     Uninstalling prompt-toolkit-1.0.18:
#       Successfully uninstalled prompt-toolkit-1.0.18
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
#   Attempting uninstall: ipython
#     Found existing installation: ipython 5.5.0
#     Uninstalling ipython-5.5.0:
#       Successfully uninstalled ipython-5.5.0
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 1.8.6
#     Uninstalling Sphinx-1.8.6:
#       Successfully uninstalled Sphinx-1.8.6
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.3.7 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 4.2.0 which is incompatible.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.29 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.34.0 which is incompatible.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# flask 1.1.4 requires click<8.0,>=5.1, but you have click 8.1.3 which is incompatible.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.1.2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed Jinja2-3.1.2 PyEnchant-3.2.2 Unidecode-1.3.4 anyio-3.6.1 black-22.3.0 click-8.1.3 css-html-js-minify-2.5.5 flake8-4.0.1 flit-3.7.1 flit-core-3.7.1 importlib-metadata-4.2.0 ipdb-0.13.9 ipython-7.34.0 isort-5.10.1 json5-0.9.8 jupyter-client-7.3.4 jupyter-server-1.17.1 jupyterlab-3.4.3 jupyterlab-server-2.14.0 mccabe-0.6.1 mypy-0.961 mypy-extensions-0.4.3 nbclassic-0.3.7 nbconvert-6.5.0 notebook-shim-0.1.0 pathspec-0.9.0 platformdirs-2.5.2 pre-commit-hooks-4.3.0 prompt-toolkit-3.0.29 pycodestyle-2.8.0 pyflakes-2.4.0 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.6 sniffio-1.2.0 sphinx-4.2.0 sphinx-copybutton-0.5.0 sphinx-material-0.0.35 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-spelling-7.5.0 toml-0.10.2 tomli-w-1.0.0 tornado-6.1 traitlets-5.2.2.post1 typed-ast-1.5.4 websocket-client-1.3.2

# %%
# !wget https://github.com/manmeet3591/rtdl/archive/refs/heads/main.zip
# Out:
# --2022-06-10 04:07:50--  https://github.com/manmeet3591/rtdl/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/manmeet3591/rtdl/zip/refs/heads/main [following]
# --2022-06-10 04:07:50--  https://codeload.github.com/manmeet3591/rtdl/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.113.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.113.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘main.zip.1’
#
# main.zip.1              [            <=>     ]  13.34M  5.80MB/s    in 2.3s
#
# 2022-06-10 04:07:52 (5.80 MB/s) - ‘main.zip.1’ saved [13988330]

# %%
# !unzip main.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/resnet/tuning/0/best.toml
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/resnet/tuning/0/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/0.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/0/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/0/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/0/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/1.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/1/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/1/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/1/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/10.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/10/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/10/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/10/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/11.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/11/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/11/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/11/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/12.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/12/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/12/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/12/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/13.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/13/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/13/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/13/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/14.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/14/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/14/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/2.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/2/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/2/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/2/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/3.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/3/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/3/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/3/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/4.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/4/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/4/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/5.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/5/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/5/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/5/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/6.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/6/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/6/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/6/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/7.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/7/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/7/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/7/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/8.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/8/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/8/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/8/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/9.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/9/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned/9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned_ensemble/
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned_ensemble/0_4/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned_ensemble/0_4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned_ensemble/0_4/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned_ensemble/10_14/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned_ensemble/10_14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned_ensemble/10_14/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned_ensemble/5_9/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned_ensemble/5_9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuned_ensemble/5_9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuning/
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuning/0.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuning/0/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuning/0/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuning/0/best.toml
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/snn/tuning/0/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/0.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/0/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/0/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/0/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/1.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/1/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/1/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/1/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/10.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/10/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/10/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/10/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/11.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/11/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/11/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/11/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/12.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/12/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/12/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/12/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/13.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/13/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/13/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/13/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/14.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/14/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/14/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/2.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/2/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/2/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/2/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/3.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/3/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/3/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/3/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/4.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/4/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/4/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/5.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/5/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/5/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/5/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/6.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/6/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/6/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/6/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/7.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/7/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/7/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/7/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/8.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/8/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/8/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/8/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/9.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/9/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned/9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned_ensemble/
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned_ensemble/0_4/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned_ensemble/0_4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned_ensemble/0_4/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned_ensemble/10_14/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned_ensemble/10_14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned_ensemble/10_14/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned_ensemble/5_9/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned_ensemble/5_9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuned_ensemble/5_9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuning/
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuning/0.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuning/0/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuning/0/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuning/0/best.toml
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/tabnet/tuning/0/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/0.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/0/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/0/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/0/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/1.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/1/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/1/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/1/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/10.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/10/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/10/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/10/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/11.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/11/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/11/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/11/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/12.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/12/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/12/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/12/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/13.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/13/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/13/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/13/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/14.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/14/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/14/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/2.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/2/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/2/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/2/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/3.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/3/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/3/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/3/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/4.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/4/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/4/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/5.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/5/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/5/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/5/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/6.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/6/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/6/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/6/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/7.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/7/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/7/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/7/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/8.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/8/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/8/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/8/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/9.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/9/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default/9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default_ensemble/
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default_ensemble/0_4/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default_ensemble/0_4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default_ensemble/0_4/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default_ensemble/10_14/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default_ensemble/10_14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default_ensemble/10_14/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default_ensemble/5_9/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default_ensemble/5_9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/default_ensemble/5_9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/0.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/0/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/0/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/0/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/1.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/1/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/1/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/1/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/10.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/10/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/10/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/10/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/11.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/11/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/11/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/11/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/12.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/12/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/12/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/12/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/13.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/13/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/13/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/13/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/14.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/14/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/14/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/2.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/2/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/2/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/2/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/3.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/3/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/3/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/3/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/4.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/4/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/4/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/5.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/5/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/5/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/5/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/6.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/6/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/6/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/6/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/7.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/7/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/7/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/7/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/8.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/8/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/8/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/8/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/9.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/9/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned/9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned_ensemble/
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned_ensemble/0_4/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned_ensemble/0_4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned_ensemble/0_4/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned_ensemble/10_14/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned_ensemble/10_14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned_ensemble/10_14/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned_ensemble/5_9/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned_ensemble/5_9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuned_ensemble/5_9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuning/
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuning/0.toml
#    creating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuning/0/
#  extracting: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuning/0/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuning/0/best.toml
#   inflating: rtdl-main/projects/revisiting-models/output/higgs_small/xgboost/tuning/0/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/jannis/
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/0.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/0/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/0/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/0/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/1.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/1/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/1/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/1/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/10.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/10/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/10/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/10/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/11.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/11/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/11/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/11/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/12.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/12/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/12/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/12/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/13.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/13/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/13/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/13/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/14.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/14/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/14/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/2.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/2/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/2/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/2/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/3.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/3/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/3/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/3/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/4.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/4/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/4/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/5.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/5/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/5/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/5/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/6.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/6/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/6/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/6/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/7.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/7/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/7/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/7/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/8.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/8/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/8/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/8/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/9.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/9/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned/9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned_ensemble/
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned_ensemble/0_4/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned_ensemble/0_4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned_ensemble/0_4/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned_ensemble/10_14/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned_ensemble/10_14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned_ensemble/10_14/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned_ensemble/5_9/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned_ensemble/5_9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuned_ensemble/5_9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuning/
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuning/0.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuning/0/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuning/0/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuning/0/best.toml
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/autoint/tuning/0/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/0.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/0/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/0/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/0/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/1.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/1/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/1/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/1/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/10.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/10/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/10/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/10/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/11.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/11/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/11/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/11/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/12.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/12/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/12/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/12/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/13.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/13/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/13/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/13/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/14.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/14/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/14/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/2.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/2/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/2/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/2/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/3.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/3/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/3/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/3/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/4.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/4/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/4/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/5.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/5/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/5/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/5/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/6.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/6/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/6/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/6/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/7.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/7/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/7/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/7/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/8.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/8/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/8/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/8/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/9.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/9/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default/9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default_ensemble/
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default_ensemble/0_4/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default_ensemble/0_4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default_ensemble/0_4/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default_ensemble/10_14/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default_ensemble/10_14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default_ensemble/10_14/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default_ensemble/5_9/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/default_ensemble/5_9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/default_ensemble/5_9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/0.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/0/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/0/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/0/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/1.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/1/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/1/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/1/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/10.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/10/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/10/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/10/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/11.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/11/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/11/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/11/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/12.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/12/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/12/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/12/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/13.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/13/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/13/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/13/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/14.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/14/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/14/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/2.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/2/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/2/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/2/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/3.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/3/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/3/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/3/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/4.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/4/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/4/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/5.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/5/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/5/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/5/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/6.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/6/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/6/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/6/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/7.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/7/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/7/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/7/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/8.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/8/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/8/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/8/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/9.toml
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/9/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned/9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned_ensemble/
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned_ensemble/0_4/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned_ensemble/0_4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned_ensemble/0_4/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned_ensemble/10_14/
#  extracting: rtdl-main/projects/revisiting-models/output/jannis/catboost/tuned_ensemble/10_14/DONE
# ...
#  extracting: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned/7/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned/7/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned/8.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned/8/
#  extracting: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned/8/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned/8/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned/9.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned/9/
#  extracting: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned/9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned/9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned_ensemble/
#    creating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned_ensemble/0_4/
#  extracting: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned_ensemble/0_4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned_ensemble/0_4/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned_ensemble/10_14/
#  extracting: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned_ensemble/10_14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned_ensemble/10_14/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned_ensemble/5_9/
#  extracting: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned_ensemble/5_9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuned_ensemble/5_9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuning/
#   inflating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuning/0.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuning/0/
#  extracting: rtdl-main/projects/revisiting-models/output/year/tabnet/tuning/0/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuning/0/best.toml
#   inflating: rtdl-main/projects/revisiting-models/output/year/tabnet/tuning/0/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/0.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/0/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default/0/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/0/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/1.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/1/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default/1/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/1/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/10.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/10/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default/10/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/10/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/11.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/11/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default/11/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/11/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/12.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/12/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default/12/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/12/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/13.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/13/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default/13/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/13/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/14.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/14/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default/14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/14/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/2.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/2/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default/2/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/2/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/3.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/3/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default/3/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/3/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/4.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/4/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default/4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/4/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/5.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/5/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default/5/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/5/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/6.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/6/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default/6/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/6/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/7.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/7/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default/7/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/7/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/8.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/8/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default/8/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/8/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/9.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/9/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default/9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default/9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default_ensemble/
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default_ensemble/0_4/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default_ensemble/0_4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default_ensemble/0_4/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default_ensemble/10_14/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default_ensemble/10_14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default_ensemble/10_14/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/default_ensemble/5_9/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/default_ensemble/5_9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/default_ensemble/5_9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/0.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/0/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/0/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/0/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/1.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/1/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/1/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/1/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/10.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/10/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/10/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/10/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/11.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/11/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/11/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/11/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/12.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/12/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/12/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/12/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/13.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/13/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/13/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/13/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/14.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/14/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/14/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/2.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/2/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/2/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/2/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/3.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/3/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/3/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/3/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/4.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/4/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/4/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/5.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/5/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/5/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/5/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/6.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/6/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/6/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/6/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/7.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/7/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/7/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/7/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/8.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/8/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/8/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/8/stats.json
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/9.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/9/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned/9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned_ensemble/
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned_ensemble/0_4/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned_ensemble/0_4/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned_ensemble/0_4/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned_ensemble/10_14/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned_ensemble/10_14/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned_ensemble/10_14/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned_ensemble/5_9/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned_ensemble/5_9/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuned_ensemble/5_9/stats.json
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuning/
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuning/0.toml
#    creating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuning/0/
#  extracting: rtdl-main/projects/revisiting-models/output/year/xgboost/tuning/0/DONE
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuning/0/best.toml
#   inflating: rtdl-main/projects/revisiting-models/output/year/xgboost/tuning/0/stats.json
#   inflating: rtdl-main/projects/revisiting-models/requirements.txt
#   inflating: rtdl-main/pyproject.toml
#   inflating: rtdl-main/requirements_dev.txt
#    creating: rtdl-main/rtdl/
#   inflating: rtdl-main/rtdl/__init__.py
#   inflating: rtdl-main/rtdl/data.py
#   inflating: rtdl-main/rtdl/functional.py
#   inflating: rtdl-main/rtdl/modules.py
#    creating: rtdl-main/rtdl/tests/
#  extracting: rtdl-main/rtdl/tests/__init__.py
#   inflating: rtdl-main/rtdl/tests/test_data.py
#   inflating: rtdl-main/rtdl/tests/test_modules.py
#   inflating: rtdl-main/rtdl/tests/test_vs_paper.py
#   inflating: rtdl-main/setup.cfg

# %%
# !cp -r  rtdl-main/projects/revisiting-models/lib .

# %%
import os
os.environ['REPO_DIR'] = '/content/rtdl-main/'
os.environ['PROJECT_DIR'] = '/content/rtdl-main/projects/revisiting-models'

# %%
# !mv rtdl_revisiting_models_data.tar.gz /content/rtdl-main/projects/revisiting-models/
os.chdir('/content/rtdl-main/projects/revisiting-models')
# !tar -xvf rtdl_revisiting_models_data.tar.gz
# Out:
# data/
# data/epsilon/
# data/epsilon/N_train.npy
# data/epsilon/idx_test.npy
# data/epsilon/y_val.npy
# data/epsilon/N_val.npy
# data/epsilon/info.json
# data/epsilon/idx_train.npy
# data/epsilon/idx_val.npy
# data/epsilon/y_test.npy
# data/epsilon/N_test.npy
# data/epsilon/y_train.npy
# data/microsoft/
# data/microsoft/N_train.npy
# data/microsoft/q_train.npy
# data/microsoft/q_test.npy
# data/microsoft/y_val.npy
# data/microsoft/q_val.npy
# data/microsoft/N_val.npy
# data/microsoft/info.json
# data/microsoft/y_test.npy
# data/microsoft/N_test.npy
# data/microsoft/y_train.npy
# data/jannis/
# data/jannis/N_train.npy
# data/jannis/idx_test.npy
# data/jannis/y_val.npy
# data/jannis/N_val.npy
# data/jannis/info.json
# data/jannis/y_test.npy
# data/jannis/N_test.npy
# data/jannis/y_train.npy
# data/helena/
# data/helena/N_train.npy
# data/helena/idx_test.npy
# data/helena/y_val.npy
# data/helena/N_val.npy
# data/helena/info.json
# data/helena/y_test.npy
# data/helena/N_test.npy
# data/helena/y_train.npy
# data/yahoo/
# data/yahoo/N_train.npy
# data/yahoo/q_train.npy
# data/yahoo/q_test.npy
# data/yahoo/y_val.npy
# data/yahoo/q_val.npy
# data/yahoo/N_val.npy
# data/yahoo/info.json
# data/yahoo/y_test.npy
# data/yahoo/N_test.npy
# data/yahoo/y_train.npy
# data/year/
# data/year/N_train.npy
# data/year/idx_test.npy
# data/year/y_val.npy
# data/year/N_val.npy
# data/year/info.json
# data/year/idx_train.npy
# data/year/idx_val.npy
# data/year/y_test.npy
# data/year/N_test.npy
# data/year/y_train.npy
# data/higgs_small/
# data/higgs_small/N_train.npy
# data/higgs_small/idx_test.npy
# data/higgs_small/y_val.npy
# data/higgs_small/N_val.npy
# data/higgs_small/info.json
# data/higgs_small/y_test.npy
# data/higgs_small/N_test.npy
# data/higgs_small/y_train.npy
# data/covtype/
# data/covtype/N_train.npy
# data/covtype/idx_test.npy
# data/covtype/y_val.npy
# data/covtype/N_val.npy
# data/covtype/info.json
# data/covtype/y_test.npy
# data/covtype/N_test.npy
# data/covtype/y_train.npy
# data/adult/
# data/adult/N_train.npy
# data/adult/C_trainval.npy
# data/adult/y_val.npy
# data/adult/N_val.npy
# data/adult/N_trainval.npy
# data/adult/info.json
# data/adult/y_trainval.npy
# data/adult/y_test.npy
# data/adult/N_test.npy
# data/adult/C_train.npy
# data/adult/y_train.npy
# data/adult/C_val.npy
# data/adult/C_test.npy
# data/california_housing/
# data/california_housing/N_train.npy
# data/california_housing/idx_test.npy
# data/california_housing/y_val.npy
# data/california_housing/N_val.npy
# data/california_housing/info.json
# data/california_housing/y_test.npy
# data/california_housing/N_test.npy
# data/california_housing/y_train.npy
# data/aloi/
# data/aloi/N_train.npy
# data/aloi/idx_test.npy
# data/aloi/y_val.npy
# data/aloi/N_val.npy
# data/aloi/info.json
# data/aloi/y_test.npy
# data/aloi/N_test.npy
# data/aloi/y_train.npy

# %%
os.chdir('/content')

# %%
import math
import typing as ty
from pathlib import Path

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import zero
from torch import Tensor

import lib
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# %%
class ResNet(nn.Module):
    def __init__(
        self,
        *,
        d_numerical: int,
        categories: ty.Optional[ty.List[int]],
        d_embedding: int,
        d: int,
        d_hidden_factor: float,
        n_layers: int,
        activation: str,
        normalization: str,
        hidden_dropout: float,
        residual_dropout: float,
        d_out: int,
    ) -> None:
        super().__init__()

        def make_normalization():
            return {'batchnorm': nn.BatchNorm1d, 'layernorm': nn.LayerNorm}[
                normalization
            ](d)

        self.main_activation = lib.get_activation_fn(activation)
        self.last_activation = lib.get_nonglu_activation_fn(activation)
        self.residual_dropout = residual_dropout
        self.hidden_dropout = hidden_dropout

        d_in = d_numerical
        d_hidden = int(d * d_hidden_factor)

        if categories is not None:
            d_in += len(categories) * d_embedding
            category_offsets = torch.tensor([0] + categories[:-1]).cumsum(0)
            self.register_buffer('category_offsets', category_offsets)
            self.category_embeddings = nn.Embedding(sum(categories), d_embedding)
            nn.init.kaiming_uniform_(self.category_embeddings.weight, a=math.sqrt(5))
            print(f'{self.category_embeddings.weight.shape}')

        self.first_layer = nn.Linear(d_in, d)
        self.layers = nn.ModuleList(
            [
                nn.ModuleDict(
                    {
                        'norm': make_normalization(),
                        'linear0': nn.Linear(
                            d, d_hidden * (2 if activation.endswith('glu') else 1)
                        ),
                        'linear1': nn.Linear(d_hidden, d),
                    }
                )
                for _ in range(n_layers)
            ]
        )
        self.last_normalization = make_normalization()
        self.head = nn.Linear(d, d_out)

    def forward(self, x_num: Tensor, x_cat: ty.Optional[Tensor]) -> Tensor:
        x = []
        if x_num is not None:
            x.append(x_num)
        if x_cat is not None:
            x.append(
                self.category_embeddings(x_cat + self.category_offsets[None]).view(
                    x_cat.size(0), -1
                )
            )
        x = torch.cat(x, dim=-1)

        x = self.first_layer(x)
        for layer in self.layers:
            layer = ty.cast(ty.Dict[str, nn.Module], layer)
            z = x
            z = layer['norm'](z)
            z = layer['linear0'](z)
            z = self.main_activation(z)
            if self.hidden_dropout:
                z = F.dropout(z, self.hidden_dropout, self.training)
            z = layer['linear1'](z)
            if self.residual_dropout:
                z = F.dropout(z, self.residual_dropout, self.training)
            x = x + z
        x = self.last_normalization(x)
        x = self.last_activation(x)
        x = self.head(x)
        x = x.squeeze(-1)
        return x

# %%
seed = 0

#[data]
normalization = 'quantile'
path = 'data/california_housing'
y_policy = 'mean_std'

#[model]
activation = 'relu'
d = 168
d_hidden_factor = 2.98304144273798
hidden_dropout = 0.4456540496119129
n_layers = 3
normalization = 'batchnorm'
residual_dropout = 0.0

#[training]
batch_size = 256
eval_batch_size = 8192
lr = 0.001759485551174299
n_epochs = 1000000000
optimizer = 'adamw'
patience = 16
weight_decay = 0.0009508455223812318

# %%
zero.set_randomness(seed)
# Out:
# 0

# %%
dataset_dir = lib.get_path(path)

# %%
stats: ty.Dict[str, ty.Any] = {
        'dataset': dataset_dir.name,
        'algorithm': 'resnet',
#        **lib.load_json(output / 'stats.json'),
    }

# %%
timer = zero.Timer()
timer.run()

# %%
dataset_dir
# Out:
# PosixPath('/content/rtdl-main/projects/revisiting-models/data/california_housing')

# %%
# !ls /content/rtdl-main/projects/revisiting-models/data/california_housing
# Out:
# idx_test.npy  N_test.npy   N_val.npy   y_train.npy
# info.json     N_train.npy  y_test.npy  y_val.npy

# %%
D = lib.Dataset.from_dir(dataset_dir)
X = D.build_X(
    normalization='quantile',
    num_nan_policy='mean',
    cat_nan_policy='new',
    cat_policy=None,
    cat_min_frequency=None,
    seed=seed,
)

# %%
if not isinstance(X, tuple):
    X = (X, None)

# %%
zero.set_randomness(seed)
Y, y_info = D.build_y(y_policy)
lib.dump_pickle(y_info,  'y_info.pickle')
X = tuple(None if x is None else lib.to_tensors(x) for x in X)
Y = lib.to_tensors(Y)
device = lib.get_device()
if device.type != 'cpu':
    X = tuple(
        None if x is None else {k: v.to(device) for k, v in x.items()} for x in X
    )
    Y_device = {k: v.to(device) for k, v in Y.items()}
else:
    Y_device = Y
X_num, X_cat = X
if not D.is_multiclass:
    Y_device = {k: v.float() for k, v in Y_device.items()}

# %%
train_size = D.size(lib.TRAIN)
batch_size = batch_size
epoch_size = stats['epoch_size'] = math.ceil(train_size / batch_size)

# %%
loss_fn = (
    F.binary_cross_entropy_with_logits
    if D.is_binclass
    else F.cross_entropy
    if D.is_multiclass
    else F.mse_loss
)
d_embedding =  None

# %%
model = ResNet(
    d_numerical=0 if X_num is None else X_num['train'].shape[1],
    categories=lib.get_categories(X_cat),
    d_out=D.info['n_classes'] if D.is_multiclass else 1,
    activation = 'relu',
    d = 168,
    d_hidden_factor = 2.98304144273798,
    hidden_dropout = 0.4456540496119129,
    n_layers = 3,
    normalization = 'batchnorm',
    residual_dropout = 0.0,
    d_embedding =  None,
).to(device)
stats['n_parameters'] = lib.get_n_parameters(model)
optimizer = lib.make_optimizer(
    optimizer,
    model.parameters(),
    lr,
    weight_decay,
)

# %%
stream = zero.Stream(lib.IndexLoader(train_size, batch_size, True, device))
progress = zero.ProgressTracker(patience)
training_log = {lib.TRAIN: [], lib.VAL: [], lib.TEST: []}
timer = zero.Timer()
checkpoint_path = 'checkpoint.pt'

# %%
def print_epoch_info():
    print(f'\n>>> Epoch {stream.epoch} | {lib.format_seconds(timer())} ')
    print(
        ' | '.join(
            f'{k} = {v}'
            for k, v in {
                'lr': lib.get_lr(optimizer),
                'batch_size': batch_size,
                'epoch_size': stats['epoch_size'],
                'n_parameters': stats['n_parameters'],
            }.items()
        )
    )

# %%
@torch.no_grad()
def evaluate(parts):
    model.eval()
    metrics = {}
    predictions = {}
    for part in parts:
        predictions[part] = (
            torch.cat(
                [
                    model(
                        None if X_num is None else X_num[part][idx],
                        None if X_cat is None else X_cat[part][idx],
                    )
                    for idx in lib.IndexLoader(
                        D.size(part),
                        eval_batch_size,
                        False,
                        device,
                    )
                ]
            )
            .cpu()
            .numpy()
        )
        metrics[part] = lib.calculate_metrics(
            D.info['task_type'],
            Y[part].numpy(),  # type: ignore[code]
            predictions[part],  # type: ignore[code]
            'logits',
            y_info,
        )
    for part, part_metrics in metrics.items():
        print(f'[{part:<5}]', lib.make_summary(part_metrics))
    return metrics, predictions

# %%
def save_checkpoint(final):
    torch.save(
        {
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'stream': stream.state_dict(),
            'random_state': zero.get_random_state(),
            **{
                x: globals()[x]
                for x in [
                    'progress',
                    'stats',
                    'timer',
                    'training_log',
                ]
            },
        },
        checkpoint_path,
    )
    # lib.dump_stats(stats, output, final)
    # lib.backup_output(output)

# %%
# %%
timer.run()
for epoch in stream.epochs(n_epochs):
    print_epoch_info()

    model.train()
    epoch_losses = []
    for batch_idx in epoch:
        optimizer.zero_grad()
        loss = loss_fn(
            model(
                None if X_num is None else X_num[lib.TRAIN][batch_idx],
                None if X_cat is None else X_cat[lib.TRAIN][batch_idx],
            ),
            Y_device[lib.TRAIN][batch_idx],
        )
        loss.backward()
        optimizer.step()
        epoch_losses.append(loss.detach())
    epoch_losses = torch.stack(epoch_losses).tolist()
    training_log[lib.TRAIN].extend(epoch_losses)
    print(f'[{lib.TRAIN}] loss = {round(sum(epoch_losses) / len(epoch_losses), 3)}')

    metrics, predictions = evaluate([lib.VAL, lib.TEST])
    for k, v in metrics.items():
        training_log[k].append(v)
    progress.update(metrics[lib.VAL]['score'])

    if progress.success:
        print('New best epoch!')
        stats['best_epoch'] = stream.epoch
        stats['metrics'] = metrics
        save_checkpoint(False)
        for k, v in predictions.items():
            np.save(f'p_{k}.npy', v)

    elif progress.fail:
        break

# %%
print('\nRunning the final evaluation...')
model.load_state_dict(torch.load(checkpoint_path)['model'])
stats['metrics'], predictions = evaluate(lib.PARTS)
for k, v in predictions.items():
    np.save(f'p_{k}.npy', v)
stats['time'] = lib.format_seconds(timer())
save_checkpoint(True)
print('Done!')
# Out:
#   0%|          | 2/52000000000 [00:00<1440153:47:03, 10.03it/s]
# >>> Epoch 1 | 0:00:00
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 58/52000000000 [00:01<254611:59:15, 56.73it/s]
# [train] loss = 0.356
# [val  ] score = -0.597 | rmse = 0.597
# [test ] score = -0.587 | rmse = 0.587
# New best epoch!
#
# >>> Epoch 2 | 0:00:01
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 114/52000000000 [00:01<221226:03:37, 65.29it/s]
# [train] loss = 0.272
# [val  ] score = -0.607 | rmse = 0.607
# [test ] score = -0.598 | rmse = 0.598
#
# >>> Epoch 3 | 0:00:02
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 163/52000000000 [00:02<244545:51:33, 59.07it/s]
# [train] loss = 0.261
# [val  ] score = -0.581 | rmse = 0.581
# [test ] score = -0.569 | rmse = 0.569
# New best epoch!
#
# >>> Epoch 4 | 0:00:03
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 213/52000000000 [00:03<248310:24:42, 58.17it/s]
# [train] loss = 0.255
# [val  ] score = -0.569 | rmse = 0.569
# [test ] score = -0.557 | rmse = 0.557
# New best epoch!
#
# >>> Epoch 5 | 0:00:03
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 263/52000000000 [00:04<232038:47:41, 62.25it/s]
# [train] loss = 0.244
# [val  ] score = -0.595 | rmse = 0.595
# [test ] score = -0.578 | rmse = 0.578
#
# >>> Epoch 6 | 0:00:04
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 321/52000000000 [00:04<220393:40:48, 65.54it/s]
# [train] loss = 0.244
# [val  ] score = -0.569 | rmse = 0.569
# [test ] score = -0.556 | rmse = 0.556
# New best epoch!
#
# >>> Epoch 7 | 0:00:05
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 370/52000000000 [00:05<239986:41:40, 60.19it/s]
# [train] loss = 0.24
# [val  ] score = -0.583 | rmse = 0.583
# [test ] score = -0.575 | rmse = 0.575
#
# >>> Epoch 8 | 0:00:06
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 424/52000000000 [00:06<246485:10:33, 58.60it/s]
# [train] loss = 0.238
# [val  ] score = -0.560 | rmse = 0.56
# [test ] score = -0.548 | rmse = 0.548
# New best epoch!
#
# >>> Epoch 9 | 0:00:06
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 474/52000000000 [00:07<246195:17:22, 58.67it/s]
# [train] loss = 0.232
# [val  ] score = -0.559 | rmse = 0.559
# [test ] score = -0.550 | rmse = 0.55
# New best epoch!
#
# >>> Epoch 10 | 0:00:07
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 523/52000000000 [00:08<277841:14:57, 51.99it/s]
# [train] loss = 0.232
# [val  ] score = -0.549 | rmse = 0.549
# [test ] score = -0.537 | rmse = 0.537
# New best epoch!
#
# >>> Epoch 11 | 0:00:08
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 579/52000000000 [00:08<272846:27:48, 52.94it/s]
# [train] loss = 0.226
# [val  ] score = -0.548 | rmse = 0.548
# [test ] score = -0.540 | rmse = 0.54
# New best epoch!
#
# >>> Epoch 12 | 0:00:09
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 633/52000000000 [00:09<242835:43:13, 59.48it/s]
# [train] loss = 0.225
# [val  ] score = -0.551 | rmse = 0.551
# [test ] score = -0.537 | rmse = 0.537
#
# >>> Epoch 13 | 0:00:10
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 675/52000000000 [00:10<206034:09:08, 70.11it/s]
# [train] loss = 0.224
# [val  ] score = -0.546 | rmse = 0.546
# [test ] score = -0.537 | rmse = 0.537
# New best epoch!
#
# >>> Epoch 14 | 0:00:10
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 735/52000000000 [00:11<274657:21:45, 52.59it/s]
# [train] loss = 0.226
# [val  ] score = -0.540 | rmse = 0.54
# [test ] score = -0.532 | rmse = 0.532
# New best epoch!
#
# >>> Epoch 15 | 0:00:11
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 785/52000000000 [00:12<243105:15:37, 59.42it/s]
# [train] loss = 0.226
# [val  ] score = -0.538 | rmse = 0.538
# [test ] score = -0.533 | rmse = 0.533
# New best epoch!
#
# >>> Epoch 16 | 0:00:12
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 835/52000000000 [00:12<228241:53:17, 63.29it/s]
# [train] loss = 0.218
# [val  ] score = -0.539 | rmse = 0.539
# [test ] score = -0.527 | rmse = 0.527
#
# >>> Epoch 17 | 0:00:13
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 892/52000000000 [00:13<240533:35:07, 60.05it/s]
# [train] loss = 0.216
# [val  ] score = -0.539 | rmse = 0.539
# [test ] score = -0.524 | rmse = 0.524
#
# >>> Epoch 18 | 0:00:14
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 941/52000000000 [00:14<238737:28:58, 60.50it/s]
# [train] loss = 0.222
# [val  ] score = -0.537 | rmse = 0.537
# [test ] score = -0.528 | rmse = 0.528
# New best epoch!
#
# >>> Epoch 19 | 0:00:14
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 997/52000000000 [00:15<236520:52:31, 61.07it/s]
# [train] loss = 0.22
# [val  ] score = -0.548 | rmse = 0.548
# [test ] score = -0.535 | rmse = 0.535
#
# >>> Epoch 20 | 0:00:15
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1045/52000000000 [00:15<231939:14:45, 62.28it/s]
# [train] loss = 0.216
# [val  ] score = -0.538 | rmse = 0.538
# [test ] score = -0.530 | rmse = 0.53
#
# >>> Epoch 21 | 0:00:16
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1100/52000000000 [00:16<238170:06:01, 60.65it/s]
# [train] loss = 0.214
# [val  ] score = -0.534 | rmse = 0.534
# [test ] score = -0.525 | rmse = 0.525
# New best epoch!
#
# >>> Epoch 22 | 0:00:17
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1152/52000000000 [00:17<240539:06:09, 60.05it/s]
# [train] loss = 0.213
# [val  ] score = -0.532 | rmse = 0.532
# [test ] score = -0.518 | rmse = 0.518
# New best epoch!
#
# >>> Epoch 23 | 0:00:18
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1201/52000000000 [00:18<247084:14:26, 58.46it/s]
# [train] loss = 0.21
# [val  ] score = -0.528 | rmse = 0.528
# [test ] score = -0.517 | rmse = 0.517
# New best epoch!
#
# >>> Epoch 24 | 0:00:18
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1258/52000000000 [00:19<222342:28:08, 64.96it/s]
# [train] loss = 0.207
# [val  ] score = -0.533 | rmse = 0.533
# [test ] score = -0.522 | rmse = 0.522
#
# >>> Epoch 25 | 0:00:19
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1301/52000000000 [00:19<234717:27:02, 61.54it/s]
# [train] loss = 0.212
# [val  ] score = -0.527 | rmse = 0.527
# [test ] score = -0.518 | rmse = 0.518
# New best epoch!
#
# >>> Epoch 26 | 0:00:20
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1357/52000000000 [00:20<254166:31:44, 56.83it/s]
# [train] loss = 0.208
# [val  ] score = -0.540 | rmse = 0.54
# [test ] score = -0.520 | rmse = 0.52
#
# >>> Epoch 27 | 0:00:21
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1410/52000000000 [00:21<252063:35:05, 57.30it/s]
# [train] loss = 0.204
# [val  ] score = -0.524 | rmse = 0.524
# [test ] score = -0.513 | rmse = 0.513
# New best epoch!
#
# >>> Epoch 28 | 0:00:21
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1460/52000000000 [00:22<231451:31:01, 62.41it/s]
# [train] loss = 0.206
# [val  ] score = -0.529 | rmse = 0.529
# [test ] score = -0.517 | rmse = 0.517
#
# >>> Epoch 29 | 0:00:22
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1514/52000000000 [00:23<235824:07:12, 61.25it/s]
# [train] loss = 0.205
# [val  ] score = -0.537 | rmse = 0.537
# [test ] score = -0.524 | rmse = 0.524
#
# >>> Epoch 30 | 0:00:23
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1562/52000000000 [00:23<243225:28:51, 59.39it/s]
# [train] loss = 0.211
# [val  ] score = -0.523 | rmse = 0.523
# [test ] score = -0.511 | rmse = 0.511
# New best epoch!
#
# >>> Epoch 31 | 0:00:24
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1613/52000000000 [00:24<238621:12:01, 60.53it/s]
# [train] loss = 0.212
# [val  ] score = -0.522 | rmse = 0.522
# [test ] score = -0.513 | rmse = 0.513
# New best epoch!
#
# >>> Epoch 32 | 0:00:25
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1672/52000000000 [00:25<233870:05:34, 61.76it/s]
# [train] loss = 0.205
# [val  ] score = -0.522 | rmse = 0.522
# [test ] score = -0.509 | rmse = 0.509
#
# >>> Epoch 33 | 0:00:25
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1721/52000000000 [00:26<231526:38:48, 62.39it/s]
# [train] loss = 0.204
# [val  ] score = -0.529 | rmse = 0.529
# [test ] score = -0.515 | rmse = 0.515
#
# >>> Epoch 34 | 0:00:26
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1777/52000000000 [00:26<225066:52:32, 64.18it/s]
# [train] loss = 0.201
# [val  ] score = -0.515 | rmse = 0.515
# [test ] score = -0.506 | rmse = 0.506
# New best epoch!
#
# >>> Epoch 35 | 0:00:27
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1826/52000000000 [00:27<228583:09:44, 63.19it/s]
# [train] loss = 0.202
# [val  ] score = -0.515 | rmse = 0.515
# [test ] score = -0.506 | rmse = 0.506
#
# >>> Epoch 36 | 0:00:28
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1875/52000000000 [00:28<229076:51:58, 63.06it/s]
# [train] loss = 0.198
# [val  ] score = -0.518 | rmse = 0.518
# [test ] score = -0.504 | rmse = 0.504
#
# >>> Epoch 37 | 0:00:28
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1930/52000000000 [00:29<230082:14:49, 62.78it/s]
# [train] loss = 0.194
# [val  ] score = -0.517 | rmse = 0.517
# [test ] score = -0.509 | rmse = 0.509
#
# >>> Epoch 38 | 0:00:29
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 1979/52000000000 [00:29<234750:34:38, 61.53it/s]
# [train] loss = 0.196
# [val  ] score = -0.515 | rmse = 0.515
# [test ] score = -0.502 | rmse = 0.502
#
# >>> Epoch 39 | 0:00:30
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2035/52000000000 [00:30<244095:51:32, 59.18it/s]
# [train] loss = 0.195
# [val  ] score = -0.511 | rmse = 0.511
# [test ] score = -0.504 | rmse = 0.504
# New best epoch!
#
# >>> Epoch 40 | 0:00:31
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2086/52000000000 [00:31<227297:54:24, 63.55it/s]
# [train] loss = 0.198
# [val  ] score = -0.513 | rmse = 0.513
# [test ] score = -0.502 | rmse = 0.502
#
# >>> Epoch 41 | 0:00:31
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2142/52000000000 [00:32<218766:01:55, 66.03it/s]
# [train] loss = 0.193
# [val  ] score = -0.513 | rmse = 0.513
# [test ] score = -0.500 | rmse = 0.5
#
# >>> Epoch 42 | 0:00:32
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2192/52000000000 [00:32<226546:06:47, 63.76it/s]
# [train] loss = 0.193
# [val  ] score = -0.513 | rmse = 0.513
# [test ] score = -0.502 | rmse = 0.502
#
# >>> Epoch 43 | 0:00:33
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2245/52000000000 [00:33<230289:31:46, 62.72it/s]
# [train] loss = 0.201
# [val  ] score = -0.519 | rmse = 0.519
# [test ] score = -0.506 | rmse = 0.506
#
# >>> Epoch 44 | 0:00:34
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2294/52000000000 [00:34<229832:22:50, 62.85it/s]
# [train] loss = 0.194
# [val  ] score = -0.517 | rmse = 0.517
# [test ] score = -0.506 | rmse = 0.506
#
# >>> Epoch 45 | 0:00:34
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2341/52000000000 [00:35<261448:12:15, 55.25it/s]
# [train] loss = 0.193
# [val  ] score = -0.511 | rmse = 0.511
# [test ] score = -0.503 | rmse = 0.503
# New best epoch!
#
# >>> Epoch 46 | 0:00:35
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2397/52000000000 [00:35<230329:01:24, 62.71it/s]
# [train] loss = 0.194
# [val  ] score = -0.512 | rmse = 0.512
# [test ] score = -0.503 | rmse = 0.503
#
# >>> Epoch 47 | 0:00:36
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2445/52000000000 [00:36<255906:33:16, 56.44it/s]
# [train] loss = 0.194
# [val  ] score = -0.512 | rmse = 0.512
# [test ] score = -0.504 | rmse = 0.504
#
# >>> Epoch 48 | 0:00:37
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2500/52000000000 [00:37<252765:43:04, 57.15it/s]
# [train] loss = 0.19
# [val  ] score = -0.507 | rmse = 0.507
# [test ] score = -0.500 | rmse = 0.5
# New best epoch!
#
# >>> Epoch 49 | 0:00:37
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2556/52000000000 [00:38<230386:35:06, 62.70it/s]
# [train] loss = 0.19
# [val  ] score = -0.509 | rmse = 0.509
# [test ] score = -0.498 | rmse = 0.498
#
# >>> Epoch 50 | 0:00:38
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2607/52000000000 [00:39<273545:39:28, 52.80it/s]
# [train] loss = 0.193
# [val  ] score = -0.513 | rmse = 0.513
# [test ] score = -0.504 | rmse = 0.504
#
# >>> Epoch 51 | 0:00:39
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2654/52000000000 [00:39<243536:03:57, 59.31it/s]
# [train] loss = 0.194
# [val  ] score = -0.511 | rmse = 0.511
# [test ] score = -0.504 | rmse = 0.504
#
# >>> Epoch 52 | 0:00:40
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2709/52000000000 [00:40<251177:04:07, 57.51it/s]
# [train] loss = 0.189
# [val  ] score = -0.512 | rmse = 0.512
# [test ] score = -0.502 | rmse = 0.502
#
# >>> Epoch 53 | 0:00:41
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2759/52000000000 [00:41<266804:51:02, 54.14it/s]
# [train] loss = 0.188
# [val  ] score = -0.508 | rmse = 0.508
# [test ] score = -0.497 | rmse = 0.497
#
# >>> Epoch 54 | 0:00:42
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2816/52000000000 [00:42<243794:12:20, 59.25it/s]
# [train] loss = 0.189
# [val  ] score = -0.506 | rmse = 0.506
# [test ] score = -0.497 | rmse = 0.497
# New best epoch!
#
# >>> Epoch 55 | 0:00:42
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2866/52000000000 [00:43<248744:05:08, 58.07it/s]
# [train] loss = 0.187
# [val  ] score = -0.515 | rmse = 0.515
# [test ] score = -0.507 | rmse = 0.507
#
# >>> Epoch 56 | 0:00:43
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2914/52000000000 [00:43<242890:25:08, 59.47it/s]
# [train] loss = 0.186
# [val  ] score = -0.506 | rmse = 0.506
# [test ] score = -0.494 | rmse = 0.494
# New best epoch!
#
# >>> Epoch 57 | 0:00:44
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 2966/52000000000 [00:44<261854:21:31, 55.16it/s]
# [train] loss = 0.187
# [val  ] score = -0.516 | rmse = 0.516
# [test ] score = -0.505 | rmse = 0.505
#
# >>> Epoch 58 | 0:00:45
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3024/52000000000 [00:45<227491:17:04, 63.49it/s]
# [train] loss = 0.186
# [val  ] score = -0.514 | rmse = 0.514
# [test ] score = -0.501 | rmse = 0.501
#
# >>> Epoch 59 | 0:00:45
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3074/52000000000 [00:46<235277:42:57, 61.39it/s]
# [train] loss = 0.186
# [val  ] score = -0.504 | rmse = 0.504
# [test ] score = -0.497 | rmse = 0.497
# New best epoch!
#
# >>> Epoch 60 | 0:00:46
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3127/52000000000 [00:47<258073:40:58, 55.97it/s]
# [train] loss = 0.184
# [val  ] score = -0.508 | rmse = 0.508
# [test ] score = -0.498 | rmse = 0.498
#
# >>> Epoch 61 | 0:00:47
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3175/52000000000 [00:47<252107:32:28, 57.29it/s]
# [train] loss = 0.182
# [val  ] score = -0.504 | rmse = 0.504
# [test ] score = -0.494 | rmse = 0.494
# New best epoch!
#
# >>> Epoch 62 | 0:00:48
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3227/52000000000 [00:48<257726:25:53, 56.05it/s]
# [train] loss = 0.188
# [val  ] score = -0.508 | rmse = 0.508
# [test ] score = -0.499 | rmse = 0.499
#
# >>> Epoch 63 | 0:00:49
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3279/52000000000 [00:49<267326:47:27, 54.03it/s]
# [train] loss = 0.186
# [val  ] score = -0.508 | rmse = 0.508
# [test ] score = -0.502 | rmse = 0.502
#
# >>> Epoch 64 | 0:00:49
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3333/52000000000 [00:50<246017:32:23, 58.71it/s]
# [train] loss = 0.181
# [val  ] score = -0.506 | rmse = 0.506
# [test ] score = -0.496 | rmse = 0.496
#
# >>> Epoch 65 | 0:00:50
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3382/52000000000 [00:51<244900:35:20, 58.98it/s]
# [train] loss = 0.184
# [val  ] score = -0.500 | rmse = 0.5
# [test ] score = -0.495 | rmse = 0.495
# New best epoch!
#
# >>> Epoch 66 | 0:00:51
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3439/52000000000 [00:51<232287:50:55, 62.18it/s]
# [train] loss = 0.181
# [val  ] score = -0.519 | rmse = 0.519
# [test ] score = -0.507 | rmse = 0.507
#
# >>> Epoch 67 | 0:00:52
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3487/52000000000 [00:52<251995:43:22, 57.32it/s]
# [train] loss = 0.179
# [val  ] score = -0.500 | rmse = 0.5
# [test ] score = -0.493 | rmse = 0.493
# New best epoch!
#
# >>> Epoch 68 | 0:00:53
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3544/52000000000 [00:53<240541:48:23, 60.05it/s]
# [train] loss = 0.183
# [val  ] score = -0.496 | rmse = 0.496
# [test ] score = -0.488 | rmse = 0.488
# New best epoch!
#
# >>> Epoch 69 | 0:00:53
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3591/52000000000 [00:54<239071:47:22, 60.42it/s]
# [train] loss = 0.18
# [val  ] score = -0.510 | rmse = 0.51
# [test ] score = -0.496 | rmse = 0.496
#
# >>> Epoch 70 | 0:00:54
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3643/52000000000 [00:54<241270:45:38, 59.87it/s]
# [train] loss = 0.181
# [val  ] score = -0.504 | rmse = 0.504
# [test ] score = -0.494 | rmse = 0.494
#
# >>> Epoch 71 | 0:00:55
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3698/52000000000 [00:55<235413:09:55, 61.36it/s]
# [train] loss = 0.185
# [val  ] score = -0.513 | rmse = 0.513
# [test ] score = -0.504 | rmse = 0.504
#
# >>> Epoch 72 | 0:00:56
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3754/52000000000 [00:56<230181:41:58, 62.75it/s]
# [train] loss = 0.183
# [val  ] score = -0.502 | rmse = 0.502
# [test ] score = -0.493 | rmse = 0.493
#
# >>> Epoch 73 | 0:00:56
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3802/52000000000 [00:57<242655:20:42, 59.53it/s]
# [train] loss = 0.184
# [val  ] score = -0.506 | rmse = 0.506
# [test ] score = -0.496 | rmse = 0.496
#
# >>> Epoch 74 | 0:00:57
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3858/52000000000 [00:58<219254:12:41, 65.88it/s]
# [train] loss = 0.177
# [val  ] score = -0.503 | rmse = 0.503
# [test ] score = -0.490 | rmse = 0.49
#
# >>> Epoch 75 | 0:00:58
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3905/52000000000 [00:58<233786:18:40, 61.78it/s]
# [train] loss = 0.181
# [val  ] score = -0.506 | rmse = 0.506
# [test ] score = -0.501 | rmse = 0.501
#
# >>> Epoch 76 | 0:00:59
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 3961/52000000000 [00:59<223623:03:37, 64.59it/s]
# [train] loss = 0.179
# [val  ] score = -0.501 | rmse = 0.501
# [test ] score = -0.496 | rmse = 0.496
#
# >>> Epoch 77 | 0:01:00
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 4009/52000000000 [01:00<230156:05:20, 62.76it/s]
# [train] loss = 0.18
# [val  ] score = -0.505 | rmse = 0.505
# [test ] score = -0.495 | rmse = 0.495
#
# >>> Epoch 78 | 0:01:00
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 4065/52000000000 [01:01<221686:07:55, 65.16it/s]
# [train] loss = 0.18
# [val  ] score = -0.505 | rmse = 0.505
# [test ] score = -0.499 | rmse = 0.499
#
# >>> Epoch 79 | 0:01:01
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 4114/52000000000 [01:01<229392:21:15, 62.97it/s]
# [train] loss = 0.179
# [val  ] score = -0.499 | rmse = 0.499
# [test ] score = -0.494 | rmse = 0.494
#
# >>> Epoch 80 | 0:01:02
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 4170/52000000000 [01:02<217152:04:59, 66.52it/s]
# [train] loss = 0.181
# [val  ] score = -0.512 | rmse = 0.512
# [test ] score = -0.500 | rmse = 0.5
#
# >>> Epoch 81 | 0:01:03
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 4218/52000000000 [01:03<227668:39:50, 63.45it/s]
# [train] loss = 0.176
# [val  ] score = -0.501 | rmse = 0.501
# [test ] score = -0.491 | rmse = 0.491
#
# >>> Epoch 82 | 0:01:03
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 4267/52000000000 [01:04<232527:56:45, 62.12it/s]
# [train] loss = 0.175
# [val  ] score = -0.510 | rmse = 0.51
# [test ] score = -0.498 | rmse = 0.498
#
# >>> Epoch 83 | 0:01:04
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 4323/52000000000 [01:04<229598:50:19, 62.91it/s]
# [train] loss = 0.17
# [val  ] score = -0.502 | rmse = 0.502
# [test ] score = -0.494 | rmse = 0.494
#
# >>> Epoch 84 | 0:01:05
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 4371/52000000000 [01:05<231384:23:12, 62.43it/s]
# [train] loss = 0.176
# [val  ] score = -0.503 | rmse = 0.503
# [test ] score = -0.493 | rmse = 0.493
#
# >>> Epoch 85 | 0:01:06
# lr = 0.001759485551174299 | batch_size = 256 | epoch_size = 52 | n_parameters = 510040
#   0%|          | 4419/52000000000 [01:06<191290:20:30, 75.51it/s]
# [train] loss = 0.172
# [val  ] score = -0.501 | rmse = 0.501
# [test ] score = -0.489 | rmse = 0.489
#
# Running the final evaluation...
# [train] score = -0.442 | rmse = 0.442
# [val  ] score = -0.496 | rmse = 0.496
# [test ] score = -0.488 | rmse = 0.488
# Done!

# %%
print(model)
# Out:
# ResNet(
#   (first_layer): Linear(in_features=8, out_features=168, bias=True)
#   (layers): ModuleList(
#     (0): ModuleDict(
#       (norm): BatchNorm1d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (linear0): Linear(in_features=168, out_features=501, bias=True)
#       (linear1): Linear(in_features=501, out_features=168, bias=True)
#     )
#     (1): ModuleDict(
#       (norm): BatchNorm1d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (linear0): Linear(in_features=168, out_features=501, bias=True)
#       (linear1): Linear(in_features=501, out_features=168, bias=True)
#     )
#     (2): ModuleDict(
#       (norm): BatchNorm1d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (linear0): Linear(in_features=168, out_features=501, bias=True)
#       (linear1): Linear(in_features=501, out_features=168, bias=True)
#     )
#   )
#   (last_normalization): BatchNorm1d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (head): Linear(in_features=168, out_features=1, bias=True)
# )
